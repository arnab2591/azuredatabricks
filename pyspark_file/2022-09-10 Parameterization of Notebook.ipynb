# %%
dbutils.notebook.run('/databricks_tutorial/Table_Notebook',0,{'Table':'A','Staging_location':'external'})
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <command-2693950582519571> in <module>
# ----> 1 dbutils.notebook.run('/databricks_tutorial/Table_Notebook',0,{'Table':'A','Staging_location':'external'})
#
# /databricks/python_shell/dbruntime/dbutils.py in run(self, path, timeout_seconds, arguments, _NotebookHandler__databricks_internal_cluster_spec)
#     201
#     202         def run(self, path, timeout_seconds, arguments={}, __databricks_internal_cluster_spec=None):
# --> 203             return self.entry_point.getDbutils().notebook()._run(
#     204                 path, timeout_seconds, arguments, __databricks_internal_cluster_spec,
#     205                 self.entry_point.getJobGroupId())
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# ...

# %%
# %run /databricks_tutorial/Table_Notebook $Table ='A' $Staging_location=9
# Out:
# 'A'
# Table is -> 'A' , staging_location is -> 9

# %%
/databricks_tutorial/Table_Notebook
