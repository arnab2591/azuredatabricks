# %%
# %fs head '/FileStore/tables/Book1.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ID,Name,Age
# ,A,23
# 2,B,
# 3,C,56
# 4,,
# 5,,
#
# </div>

# %%
# %fs head "/FileStore/tables/Fillna.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ID,Name,Age
# 1,A,12
# 2,B,
# 3,,
# ,D,11
#
# </div>

# %%
df = spark.read.option('header',True).csv('/FileStore/tables/Fillna.csv').cache()
df.count()
# Out:
# Out[5]: 4

# %%
import pyspark
df1 = spark.read.option('header',True).csv('/FileStore/tables/Book1-1.csv').cache()
df1.count()
# Out:
# Out[11]: 5

# %%
import pyspark
df2 = spark.read.option('header',True).csv('/FileStore/tables/Book1.csv').persist(pyspark.StorageLevel.DISK_ONLY)
df2.count()
# Out:
# Out[10]: 5

# %%
df1.unpersist()
# Out:
# Out[13]: DataFrame[ID: string, Name: string, Age: string]

# %%
# %sql
cache table table_name_test OPTIONS (StorageLevel 'DISK_ONLY') select 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
cache table table_name_test2 select 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
uncache table table_name_test2
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
clear cache
