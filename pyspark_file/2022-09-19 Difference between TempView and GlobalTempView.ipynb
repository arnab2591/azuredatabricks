# %%
df = spark.read.format("parquet").load("/user/hive/warehouse/Employee/")
df.show()
# Out:
# +---+------+------+----+
# | ID|  Name|Salary|Year|
# +---+------+------+----+
# |  2|Shivam| 20000|2001|
# | 10|Sourav| 25000|2004|
# |  7| Kunal| 27000|2003|
# |  8| Bishu| 39000|2003|
# |  6| Arnab| 15000|2002|
# |  4| Kunal| 22000|2001|
# |  1| Sagar| 10000|2000|
# |  3|  Alex| 15000|2000|
# |  9|  Arun| 18000|2004|
# |  5|   Kim| 13000|2002|
# +---+------+------+----+

# %%
df.createOrReplaceTempView("Test")

# %%
# %sql
Select * from Test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.createTempView("Test")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-3346191065630826> in <module>
# ----> 1 df.createTempView("Test")
#
# /databricks/spark/python/pyspark/sql/dataframe.py in createTempView(self, name)
#     173
#     174         """
# --> 175         self._jdf.createTempView(name)
#     176
#     177     def createOrReplaceTempView(self, name):
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# ...

# %%
df.createOrReplaceGlobalTempView("Test_global")

# %%
# %sql

Select * from global_temp.Test_global;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
