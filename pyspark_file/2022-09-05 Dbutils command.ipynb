# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
# ...

# %%
dbutils.fs.ls('/FileStore/tables/student1')
# Out:
# Out[2]: [FileInfo(path='dbfs:/FileStore/tables/student1/student_database.csv', name='student_database.csv', size=71, modificationTime=1662300002000),
#  FileInfo(path='dbfs:/FileStore/tables/student1/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662300143000),
#  FileInfo(path='dbfs:/FileStore/tables/student1/student_database2.csv', name='student_database2.csv', size=76, modificationTime=1662300349000)]

# %%
dbutils.fs.mkdirs('/FileStore/tables/student3')
# Out:
# Out[7]: True

# %%
dbutils.fs.cp('FileStore/tables/student1/student_database.csv','/FileStore/tables/student3',True)
# Out:
# Out[8]: True

# %%
dbutils.fs.ls('/FileStore/tables/student3')
# Out:
# Out[9]: [FileInfo(path='dbfs:/FileStore/tables/student3/student_database.csv', name='student_database.csv', size=71, modificationTime=1662406611000)]

# %%
dbutils.fs.cp('FileStore/tables/student1/','/FileStore/tables/student3',True)
# Out:
# Out[10]: True

# %%
dbutils.fs.ls('/FileStore/tables/student3')
# Out:
# Out[11]: [FileInfo(path='dbfs:/FileStore/tables/student3/student_database.csv', name='student_database.csv', size=71, modificationTime=1662406807000),
#  FileInfo(path='dbfs:/FileStore/tables/student3/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662406808000),
#  FileInfo(path='dbfs:/FileStore/tables/student3/student_database2.csv', name='student_database2.csv', size=76, modificationTime=1662406808000)]

# %%
dbutils.fs.rm('/FileStore/tables/student3/student_database2.csv',True)
# Out:
# Out[12]: True

# %%
dbutils.fs.ls('/FileStore/tables/student3')
# Out:
# Out[13]: [FileInfo(path='dbfs:/FileStore/tables/student3/student_database.csv', name='student_database.csv', size=71, modificationTime=1662406807000),
#  FileInfo(path='dbfs:/FileStore/tables/student3/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662406808000)]

# %%
dbutils.fs.mv('FileStore/tables/student1/student_database2.csv','FileStore/tables/student3/student_database2.csv',True)
# Out:
# Out[14]: True

# %%
dbutils.fs.ls('/FileStore/tables/student3')
# Out:
# Out[15]: [FileInfo(path='dbfs:/FileStore/tables/student3/student_database.csv', name='student_database.csv', size=71, modificationTime=1662406807000),
#  FileInfo(path='dbfs:/FileStore/tables/student3/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662406808000),
#  FileInfo(path='dbfs:/FileStore/tables/student3/student_database2.csv', name='student_database2.csv', size=76, modificationTime=1662407134000)]

# %%
dbutils.fs.ls('/FileStore/tables/student1')
# Out:
# Out[16]: [FileInfo(path='dbfs:/FileStore/tables/student1/student_database.csv', name='student_database.csv', size=71, modificationTime=1662300002000),
#  FileInfo(path='dbfs:/FileStore/tables/student1/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662300143000)]

# %%
dbutils.fs.put('/FileStore/tables/student1/d.txt',str('Sagar'),True)
# Out:
# Wrote 5 bytes.
# Out[17]: True

# %%
dbutils.fs.ls('/FileStore/tables/student1')
# Out:
# Out[18]: [FileInfo(path='dbfs:/FileStore/tables/student1/d.txt', name='d.txt', size=5, modificationTime=1662407416000),
#  FileInfo(path='dbfs:/FileStore/tables/student1/student_database.csv', name='student_database.csv', size=71, modificationTime=1662300002000),
#  FileInfo(path='dbfs:/FileStore/tables/student1/student_database1.csv', name='student_database1.csv', size=87, modificationTime=1662300143000)]

# %%
dbutils.fs.head('/FileStore/tables/student1/d.txt',5)
# Out:
# Out[20]: 'Sagar'

# %%
dbutils.fs.head('/FileStore/tables/student1/student_database.csv',50)
# Out:
# [Truncated to first 50 bytes]
# Out[22]: 'ID,Name,Age\r\n1,Sagar,24\r\n2,Shivam,23\r\n3,Alex,34\r\n4'
