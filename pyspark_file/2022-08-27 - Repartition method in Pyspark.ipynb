22</td><td>0</td></tr><tr><td>69</td><td>38.90457478</td><td>24</td><td>0</td></tr><tr><td>85</td><td>18.85676916</td><td>22</td><td>0</td></tr><tr><td>52</td><td>48.84032591</td><td>22</td><td>1</td></tr><tr><td>64</td><td>40.91564054</td><td>22</td><td>0</td></tr><tr><td>95</td><td>26.689641</td><td>21</td><td>1</td></tr><tr><td>51</td><td>27.36983156</td><td>43</td><td>1</td></tr><tr><td>61</td><td>18.74367404</td><td>75</td><td>0</td></tr><tr><td>50</td><td>34.69215364</td><td>59</td><td>1</td></tr><tr><td>66</td><td>35.69006444</td><td>21</td><td>1</td></tr><tr><td>68</td><td>21.28939986</td><td>21</td><td>0</td></tr><tr><td>41</td><td>37.74364919</td><td>24</td><td>0</td></tr><tr><td>83</td><td>41.82779545</td><td>54</td><td>1</td></tr><tr><td>49</td><td>21.25090802</td><td>21</td><td>0</td></tr><tr><td>86</td><td>18.42115782</td><td>32</td><td>0</td></tr><tr><td>54</td><td>18.72768438</td><td>31</td><td>0</td></tr><tr><td>79</td><td>20.85675608</td><td>25</td><td>0</td></tr><tr><td>85</td><td>21.12849033</td><td>25</td><td>0</td></tr><tr><td>50</td><td>18.52234384</td><td>21</td><td>0</td></tr><tr><td>78</td><td>28.51821883</td><td>21</td><td>0</td></tr><tr><td>42</td><td>33.89639518</td><td>21</td><td>1</td></tr><tr><td>87</td><td ...

# %%
dbutils.fs.rm('/FileStore/tables/Diabetic_Data',True)
# Out:
# Out[7]: True

# %%
df.write.format("parquet").mode("overwrite").save("/FileStore/tables/Diabetic_Data")

# %%
# %sql
select count(*) from parquet.`/FileStore/tables/Diabetic_Data/part-00000-tid-4245850745351810011-2f9266ec-5bc2-40c0-a831-344f065ec96a-6-1-c000.snappy.parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>10000</td></tr></tbody></table></div>

# %%
# storing a file in 5 partition equally
df.repartition(5).write.format("parquet").mode("overwrite").save("/FileStore/tables/Diabetic_Data1")

# %%
# %sql
select count(*) from parquet.`/FileStore/tables/Diabetic_Data1/part-00000-tid-530304819920627090-dea5961c-e524-4484-8321-f0f24b34b9b5-11-1-c000.snappy.parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>2000</td></tr></tbody></table></div>

# %%
# storing a file by partitionBy command using Diabetic column
df.write.format("parquet").partitionBy("Diabetic").mode("overwrite").save("/FileStore/tables/Diabetic_Data2")

# %%
# %sql
select count(*) from parquet.`/FileStore/tables/Diabetic_Data2/Diabetic=0/part-00000-tid-2184142841195521317-93e456ba-2013-4ca6-8e35-58cbc1521950-19-1.c000.snappy.parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>6656</td></tr></tbody></table></div>

# %%
# storing a file using repartition and partitionBy both command using Diabetic column
df.repartition(3).write.format("parquet").partitionBy("Diabetic").mode("overwrite").save("/FileStore/tables/Diabetic_Data3")

# %%
# %sql
select count(*) from parquet.`/FileStore/tables/Diabetic_Data3/Diabetic=0/part-00000-tid-4724119093511545493-4984932c-a867-44ad-b966-7f255a64e083-24-1.c000.snappy.parquet`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>2240</td></tr></tbody></table></div>
