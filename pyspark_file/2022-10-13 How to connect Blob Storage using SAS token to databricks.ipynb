# %%
spark.conf.set(f"fs.azure.sas.{container}.{storageAccountName}.blob.core.windows.net",sasKey)

# %%
spark.conf.set(f"fs.azure.sas.source.databricksblobstorage1.blob.core.windows.net",'?sv=2021-06-08&ss=bfqt&srt=sco&sp=ltfx&se=2022-10-14T12:03:31Z&st=2022-10-14T04:03:31Z&spr=https&sig=eCNvaSi4XUgkyYVd5FZKuKFdo8y7Mu1O4Ef%2BttnGGhQ%3D')

# %%
#dbutils.fs.ls('wasbs://{container}@{storageAccountName}.blob.core.windows.net')
dbutils.fs.ls('wasbs://source@databricksblobstorage1.blob.core.windows.net')
# Out:
# Out[2]: [FileInfo(path='wasbs://source@databricksblobstorage1.blob.core.windows.net/Book1.csv', name='Book1.csv', size=68, modificationTime=1665636235000),
#  FileInfo(path='wasbs://source@databricksblobstorage1.blob.core.windows.net/Demo_2.xml', name='Demo_2.xml', size=1474, modificationTime=1665636235000),
#  FileInfo(path='wasbs://source@databricksblobstorage1.blob.core.windows.net/Fillna.csv', name='Fillna.csv', size=39, modificationTime=1665636235000),
#  FileInfo(path='wasbs://source@databricksblobstorage1.blob.core.windows.net/Insert_file.csv', name='Insert_file.csv', size=29, modificationTime=1665636235000),
#  FileInfo(path='wasbs://source@databricksblobstorage1.blob.core.windows.net/demo.xml', name='demo.xml', size=233, modificationTime=1665636235000)]

# %%
spark.read.csv('wasbs://source@databricksblobstorage1.blob.core.windows.net/Fillna.csv')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-3360331262573172> in <module>
# ----> 1 spark.read.csv('wasbs://source@databricksblobstorage1.blob.core.windows.net/Fillna.csv')
#
# /databricks/spark/python/pyspark/sql/readwriter.py in csv(self, path, schema, sep, encoding, quote, escape, comment, header, inferSchema, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, nullValue, nanValue, positiveInf, negativeInf, dateFormat, timestampFormat, maxColumns, maxCharsPerColumn, maxMalformedLogPerPartition, mode, columnNameOfCorruptRecord, multiLine, charToEscapeQuoteEscaping, samplingRatio, enforceSchema, emptyValue, locale, lineSep, pathGlobFilter, recursiveFileLookup, modifiedBefore, modifiedAfter, unescapedQuoteHandling)
#     408             path = [path]
#     409         if type(path) == list:
# ...

# %%
spark.conf.set(f"fs.azure.sas.source.databricksblobstorage1.blob.core.windows.net",'?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-10-14T12:09:58Z&st=2022-10-14T04:09:58Z&spr=https&sig=6OsMt9uGh5o9l498Cg11Na6QaNcLRBQuWwmgcOXCWr8%3D')

# %%
df=spark.read.option("header",True).csv('wasbs://source@databricksblobstorage1.blob.core.windows.net/Fillna.csv')
df.show()
# Out:
# +----+----+----+
# |  ID|Name| Age|
# +----+----+----+
# |   1|   A|  12|
# |   2|   B|null|
# |   3|null|null|
# |null|   D|  11|
# +----+----+----+

# %%
df.write.mode('overwrite').format('parquet').save('wasbs://source@databricksblobstorage1.blob.core.windows.net/Testing_output_fromdatabricks')

# %%
df1=spark.read.parquet('wasbs://source@databricksblobstorage1.blob.core.windows.net/Testing_output_fromdatabricks')
df1.show()
# Out:
# +----+----+----+
# |  ID|Name| Age|
# +----+----+----+
# |   1|   A|  12|
# |   2|   B|null|
# |   3|null|null|
# |null|   D|  11|
# +----+----+----+

# %%
df1=spark.read.parquet('wasbs://source@databricksblobstorage1.blob.core.windows.net/Testing_output_fromdatabricks/part-00000-tid-7295972069547135001-5d3b50b8-7270-407c-a75e-ba3f71699717-3-1-c000.snappy.parquet')
df1.show()
# Out:
# +----+----+----+
# |  ID|Name| Age|
# +----+----+----+
# |   1|   A|  12|
# |   2|   B|null|
# |   3|null|null|
# |null|   D|  11|
# +----+----+----+
