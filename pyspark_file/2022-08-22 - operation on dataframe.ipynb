# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/Sample-1.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>Name</th><th>Age</th><th>Country</th></tr></thead><tbody><tr><td>1</td><td>Sagar</td><td>20</td><td>India</td></tr><tr><td>2</td><td>Shivam</td><td>23</td><td>India</td></tr><tr><td>3</td><td>Muni</td><td>26</td><td>India</td></tr><tr><td>1</td><td>Sagar</td><td>30</td><td>India</td></tr></tbody></table></div>

# %%
df.show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# |  3|  Muni| 26|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+

# %%
#1st Method
df.sort(df.ID).show()# Default is ascending order
df.sort(df.ID.desc()).show()# Descending order
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 20|  India|
# |  1| Sagar| 30|  India|
# |  2|Shivam| 23|  India|
# |  3|  Muni| 26|  India|
# +---+------+---+-------+
#
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  3|  Muni| 26|  India|
# |  2|Shivam| 23|  India|
# |  1| Sagar| 20|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+

# %%
#2nd Method
df.orderBy(df.ID.desc()).show()# Descending order
df.orderBy(df.ID.desc(),df.Age).show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  3|  Muni| 26|  India|
# |  2|Shivam| 23|  India|
# |  1| Sagar| 20|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+
#
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  3|  Muni| 26|  India|
# |  2|Shivam| 23|  India|
# |  1| Sagar| 20|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+

# %%
from pyspark.sql.functions import col
df.orderBy(col("ID").desc(),col("Age").asc()).show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  3|  Muni| 26|  India|
# |  2|Shivam| 23|  India|
# |  1| Sagar| 20|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+

# %%
df.show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# |  3|  Muni| 26|  India|
# |  1| Sagar| 30|  India|
# +---+------+---+-------+

# %%
df1=spark.createDataFrame([[1,'Sagar',20,'India'],[3,'Muni',26,'India']])
df = df.union(df1)
df.show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# |  3|  Muni| 26|  India|
# |  1| Sagar| 30|  India|
# |  1| Sagar| 20|  India|
# |  3|  Muni| 26|  India|
# +---+------+---+-------+

# %%
#1st method
df1 = df.distinct()
df1.show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 30|  India|
# |  3|  Muni| 26|  India|
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# +---+------+---+-------+

# %%
#2nd Method
df.dropDuplicates().show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 30|  India|
# |  3|  Muni| 26|  India|
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# +---+------+---+-------+

# %%
df.dropDuplicates(["ID","Name"]).show()
# Out:
# +---+------+---+-------+
# | ID|  Name|Age|Country|
# +---+------+---+-------+
# |  1| Sagar| 20|  India|
# |  2|Shivam| 23|  India|
# |  3|  Muni| 26|  India|
# +---+------+---+-------+

# %%
# File location and type
file_location = "/FileStore/tables/Sample-2.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

df.show()
# Out:
# +---+------+-----+
# | ID|  Name|Marks|
# +---+------+-----+
# |  1| Sagar|   50|
# |  2|Shivam|   40|
# |  3|  Muni|   20|
# |  1| Sagar|   80|
# |  2|Shivam|   10|
# |  3|  Muni|   90|
# +---+------+-----+

# %%
df1 = df.groupBy('ID').max('Marks')
df1.show()
# Out:
# +---+----------+
# | ID|max(Marks)|
# +---+----------+
# |  1|        80|
# |  3|        90|
# |  2|        40|
# +---+----------+

# %%
df1 = df.groupBy('ID','Name').max('Marks')
df1 = df1.withColumnRenamed('max(Marks)','Marks_Max')
df1.show()
# Out:
# +---+------+---------+
# | ID|  Name|Marks_Max|
# +---+------+---------+
# |  2|Shivam|       40|
# |  3|  Muni|       90|
# |  1| Sagar|       80|
# +---+------+---------+

# %%
from pyspark.sql import functions as F
df1 = df.groupBy('ID','Name').agg(F.max('Marks').alias('Marks_Max'),F.min('Marks').alias('Marks_Min'),F.sum('Marks').alias('Marks_Sum'))
df1.show()
# Out:
# +---+------+---------+---------+---------+
# | ID|  Name|Marks_Max|Marks_Min|Marks_Sum|
# +---+------+---------+---------+---------+
# |  2|Shivam|       40|       10|       50|
# |  3|  Muni|       90|       20|      110|
# |  1| Sagar|       80|       50|      130|
# +---+------+---------+---------+---------+

# %%
# Create a view or table

temp_table_name = "Sample-1_csv"

df.createOrReplaceTempView(temp_table_name)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-1906862405001115> in <module>
#       3 temp_table_name = "Sample-1_csv"
#       4
# ----> 5 df.createOrReplaceTempView(temp_table_name)
#
# /databricks/spark/python/pyspark/sql/dataframe.py in createOrReplaceTempView(self, name)
#     194
#     195         """
# --> 196         self._jdf.createOrReplaceTempView(name)
#     197
#     198     def createGlobalTempView(self, name):
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /databricks/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     121                 # Hide where the exception came from that shows a non-Pythonic
#     122                 # JVM exception message.
# --> 123                 raise converted from None
#     124             else:
#     125                 raise
#
# AnalysisException: Invalid view name: Sample-1_csv

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `Sample-1_csv`
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "Sample-1_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
