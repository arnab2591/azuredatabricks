# %%
dbutils.widgets.text('Table','')

# %%
a = dbutils.widgets.get('Table')
print(a)
# Out:
# 43

# %%
dbutils.widgets.text('Staging_location','')

# %%
staging_location = dbutils.widgets.get('Staging_location')
print('Table is ->',a,', staging_location is ->',staging_location)
# Out:
# Table is ->  , staging_location is ->
